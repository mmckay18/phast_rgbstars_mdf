# %% [markdown]
# # This notebook is for building visuals based on 2024 analysis and simplifying where the data is coming from and being handled.

# %% [markdown]
# # M31 catalog table
#
# 1. Full catalogs that were reduced using the Z24 GST criteria combined to a single catalog: /Users/mmckay/phd_projects/analysis_routine/DATA/m31_photometry_gst_optical_catalog_13689259.csv
#     - Reduction script:/Users/mmckay/phd_projects/analysis_routine/code/photometry_fns/photmetry_catalog_preprocessing_fn.py
#     - Appending catalogs script: /Users/mmckay/phd_projects/analysis_routine/code/m31_data_merging.ipynb
#
# 2.

# %% [markdown]
# Fully r
